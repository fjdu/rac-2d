# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('/share/home/fjdu/projects/ppd/my_python_lib/')
from draw import long_function_definitions
mycm = long_function_definitions.make_my_colormap(
    c_list=[(0.0, (0.5, 0.0, 0.5)),
            (0.2, (0.0, 0.0, 1.0)),
            (0.4, (0.0, 0.8, 1.0)),
            (0.6, (0.0, 0.8, 0.0)),
            (0.8, (1.0, 0.8, 0.0)),
            (1.0, (1.0, 0.0, 0.0))])

# %%
for m in ['20180116_1', '20180116_2', '20180116_3', '20180116_4']:
    _p = '/share/home/fjdu/projects/ppd/tests_photon_prop/' + m + '/iter_0000.dat'
    d = long_function_definitions.load_data_as_dic(_p)
    long_function_definitions.plot_model_results_map(d,
                                                     [
                                                         [{'name': 'n_gas',
                                                           'linearscale': False,
                                                           'cmap': mycm,
                                                           'vr': (1e3, 1e13),
                                                           'name_disp': r'$n_{\rm gas}$ (cm$^{-3}$)'}],
                                                     ],
                                                     xRange=(0.0, 10), yRange=(0,4),
                                                    )
# Out:
# n_gas        Max, min   2.1228e+16  1.8043e+01
# n_gas        Max, min   5.3289e+16  3.6418e+02
# n_gas        Max, min   6.2755e+16  3.1590e+01
# n_gas        Max, min   3.4525e+16  8.7993e+01

# %%
for m in ['20180116_3', '20180116_4']:
    _p = '/share/home/fjdu/projects/ppd/tests_photon_prop/' + m + '/iter_0001.dat'
    d = long_function_definitions.load_data_as_dic(_p)
    long_function_definitions.plot_model_results_map(d,
                                                     [
                                                         [{'name': 'n_gas',
                                                           'linearscale': False,
                                                           'cmap': mycm,
                                                           'vr': (1e3, 1e13),
                                                           'name_disp': r'$n_{\rm gas}$ (cm$^{-3}$)'}],
                                                     ],
                                                     xRange=(0.0, 15), yRange=(0,6),
                                                    )
# Out:
# n_gas        Max, min   6.2755e+16  3.1590e+01
# n_gas        Max, min   3.4525e+16  8.7993e+01

# %%
for m in ['20180116_1', '20180116_2', '20180116_3', '20180116_4']:
    _p = '/share/home/fjdu/projects/ppd/tests_photon_prop/' + m + '/iter_0000.dat'
    d = long_function_definitions.load_data_as_dic(_p)
    long_function_definitions.plot_model_results_map(d,
                                                     [
                                                         [{'name': 'Tdust',
                                                           'linearscale': False,
                                                           'cmap': mycm,
                                                           'vr': (5, 300),
                                                           'name_disp': r'$T_{\rm dust}$ (K)'}],
                                                     ],
                                                     xRange=(0.0, 20), yRange=(0, 10),
                                                     edge_width=0.1
                                                    )
# Out:
# Tdust        Max, min   3.4320e+03  1.8820e+01
# Tdust        Max, min   2.4937e+03  5.0000e+00
# Tdust        Max, min   1.9105e+03  5.0000e+00
# Tdust        Max, min   1.8832e+03  5.0000e+00
