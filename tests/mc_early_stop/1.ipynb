# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('/share/home/fjdu/projects/ppd/my_python_lib/')
from draw import long_function_definitions
from draw import drawing

mycm = long_function_definitions.make_my_colormap(
    c_list=[(0.0, (0.5, 0.0, 0.5)),
            (0.2, (0.0, 0.0, 1.0)),
            (0.4, (0.0, 0.8, 1.0)),
            (0.6, (0.0, 0.8, 0.0)),
            (0.8, (1.0, 0.8, 0.0)),
            (1.0, (1.0, 0.0, 0.0))])

# %%
fig = figure(figsize=(12,12))
ax_s = drawing.my_axes_grid(2, 2, fig=fig, xlim=(0,20), ylim=(0,10))
i = 0
locs = {'20180116_1': (0,0), '20180116_2':(0,1), '20180116_3':(1,0), '20180116_4':(1,1)}
labels = {'20180116_1':'Inf', '20180116_2':200000, '20180116_3':20000, '20180116_4':2000}
fig.text(0.5, 1.02, r'$n_{\rm gas}$ (cm$^{-3}$)', fontsize=25, horizontalalignment='center', verticalalignment='top')
for m in locs:
    _p = '/share/home/fjdu/projects/ppd/tests_photon_prop/' + m + '/iter_0000.dat'
    d = long_function_definitions.load_data_as_dic(_p)
    iloc = locs[m]
    long_function_definitions.plot_model_results_map(d,
                                                     [
                                                         [{'name': 'n_gas',
                                                           'linearscale': False,
                                                           'cmap': mycm,
                                                           'vr': (1e3, 1e13),
                                                           'name_disp': 'nmax_encounter={v}'.format(v=labels[m])}],
                                                     ],
                                                     xRange=(0.0, 20), yRange=(0, 10),
                                                     fig_prev=fig, ax_prev=ax_s[iloc[0]][iloc[1]],
                                                     showColorbar=True if i==0 else False,
                                                     ax_cbar=fig.add_axes((1,0.15,0.02,0.7))
                                                    )
    i = i + 1
# Out:
# n_gas        Max, min   4.4826e+16  2.4261e+01
# n_gas        Max, min   6.2755e+16  3.1590e+01
# n_gas        Max, min   4.1215e+16  1.9096e+01
# n_gas        Max, min   3.4525e+16  8.7993e+01

# %%
fig = figure(figsize=(12,12))
ax_s = drawing.my_axes_grid(2, 2, fig=fig, xlim=(0,0.6), ylim=(0,0.2))
i = 0
locs = {'20180116_1': (0,0), '20180116_2':(0,1), '20180116_3':(1,0), '20180116_4':(1,1)}
labels = {'20180116_1':'Inf', '20180116_2':200000, '20180116_3':20000, '20180116_4':2000}
fig.text(0.5, 1.02, r'$n_{\rm gas}$ (cm$^{-3}$)', fontsize=25, horizontalalignment='center', verticalalignment='top')
for m in locs:
    _p = '/share/home/fjdu/projects/ppd/tests_photon_prop/' + m + '/iter_0000.dat'
    d = long_function_definitions.load_data_as_dic(_p)
    iloc = locs[m]
    long_function_definitions.plot_model_results_map(d,
                                                     [
                                                         [{'name': 'n_gas',
                                                           'linearscale': False,
                                                           'cmap': mycm,
                                                           'vr': (1e3, 1e16),
                                                           'name_disp': 'nmax_encounter={v}'.format(v=labels[m])}],
                                                     ],
                                                     xRange=(0.0, 0.6), yRange=(0, 0.5),
                                                     fig_prev=fig, ax_prev=ax_s[iloc[0]][iloc[1]],
                                                     showColorbar=True if i==0 else False,
                                                     ax_cbar=fig.add_axes((1,0.15,0.02,0.7))
                                                    )
    i = i + 1
# Out:
# n_gas        Max, min   4.4826e+16  2.4261e+01
# n_gas        Max, min   6.2755e+16  3.1590e+01
# n_gas        Max, min   4.1215e+16  1.9096e+01
# n_gas        Max, min   3.4525e+16  8.7993e+01

# %%
fig = figure(figsize=(12,12))
ax_s = drawing.my_axes_grid(2, 2, fig=fig, xlim=(0,20), ylim=(0,10))
i = 0
locs = {'20180116_1': (0,0), '20180116_2':(0,1), '20180116_3':(1,0), '20180116_4':(1,1)}
labels = {'20180116_1':'Inf', '20180116_2':200000, '20180116_3':20000, '20180116_4':2000}
fig.text(0.5, 1.02, r'$T_{\rm dust}$ (K)', fontsize=25, horizontalalignment='center', verticalalignment='top')
for m in locs:
    _p = '/share/home/fjdu/projects/ppd/tests_photon_prop/' + m + '/iter_0000.dat'
    d = long_function_definitions.load_data_as_dic(_p)
    iloc = locs[m]
    long_function_definitions.plot_model_results_map(d,
                                                     [
                                                         [{'name': 'Tdust',
                                                           'linearscale': False,
                                                           'cmap': mycm,
                                                           'vr': (5, 300),
                                                           'name_disp': 'nmax_encounter={v}'.format(v=labels[m])}],
                                                     ],
                                                     xRange=(0.0, 20), yRange=(0, 10),
                                                     fig_prev=fig, ax_prev=ax_s[iloc[0]][iloc[1]],
                                                     showColorbar=True if i==0 else False,
                                                     ax_cbar=fig.add_axes((1,0.15,0.02,0.7))
                                                    )
    i = i + 1
# Out:
# Tdust        Max, min   2.4953e+03  5.0000e+00
# Tdust        Max, min   1.9105e+03  5.0000e+00
# Tdust        Max, min   3.4336e+03  5.0000e+00
# Tdust        Max, min   1.8832e+03  5.0000e+00

# %%
fig = figure(figsize=(12,12))
ax_s = drawing.my_axes_grid(2, 2, fig=fig, xlim=(0,20), ylim=(0,10))
i = 0
locs = {'20180116_1': (0,0), '20180116_2':(0,1), '20180116_3':(1,0), '20180116_4':(1,1)}
labels = {'20180116_1':'Inf', '20180116_2':200000, '20180116_3':20000, '20180116_4':2000}
fig.text(0.5, 1.02, r'$G_{0,\rm UV}$', fontsize=25, horizontalalignment='center', verticalalignment='top')
for m in locs:
    _p = '/share/home/fjdu/projects/ppd/tests_photon_prop/' + m + '/iter_0000.dat'
    d = long_function_definitions.load_data_as_dic(_p)
    iloc = locs[m]
    long_function_definitions.plot_model_results_map(d,
                                                     [
                                                         [{'name': 'G0_UV',
                                                           'linearscale': False,
                                                           'cmap': mycm,
                                                           'vr': (1e-2, 1e6),
                                                           'name_disp': 'nmax_encounter={v}'.format(v=labels[m])}],
                                                     ],
                                                     xRange=(0.0, 20), yRange=(0, 10),
                                                     fig_prev=fig, ax_prev=ax_s[iloc[0]][iloc[1]],
                                                     showColorbar=True if i==0 else False,
                                                     ax_cbar=fig.add_axes((1,0.15,0.02,0.7))
                                                    )
    i = i + 1
# Out:
# G0_UV        Max, min   1.2919e+10  0.0000e+00
# G0_UV        Max, min   1.3355e+10  0.0000e+00
# G0_UV        Max, min   1.2844e+10 -1.9043e-10
# G0_UV        Max, min   1.3088e+10  0.0000e+00
